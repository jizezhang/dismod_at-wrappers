# %%
import sys
sys.path.insert(0, '../code/')
import pandas as pd
import covariate
import numpy as np

# %%
measurement = pd.read_csv('./data/copd/copd_sincidence.csv', low_memory=False)[['location_id', 'sex', 'age_start', 'age_end',
        'year_start', 'year_end', 'mean', 'standard_error', 'measure']]
elevation = pd.read_csv('./data/copd/elevation.csv')[['location_id', 'sex_id', 'age_group_id', 'year_id', 'mean_value']]
ldi = pd.read_csv('./data/copd/ldi.csv')[['location_id', 'sex_id', 'age_group_id', 'year_id', 'mean_value']]
sev = pd.read_csv('./data/copd/sev_copd.csv')[['location_id', 'sex_id', 'age_group_id', 'year_id', 'mean_value']]
population = pd.read_csv('./data/pop.csv')[['location_id', 'sex_id', 'age_group_id', 'year_id', 'population']]
measurement.dropna(inplace=True)
sev['age_group_id'] = 22

# %%
elevation.dropna(inplace=True)
ldi.dropna(inplace=True)
sev.dropna(inplace=True)
population.dropna(inplace=True)
measurement = measurement.reset_index(drop=True)

# %%
measurement.head()
# Out:
#    location_id     sex  age_start  age_end  year_start  year_end      mean  \
# 0           71  Female         50       59        2005      2006  0.108689
# 1           71  Female         60       69        2005      2006  0.220574
# 2           71    Male         40       49        2005      2006  0.054871
# 3           71    Male         50       59        2005      2006  0.083323
# 4           71    Male         60       69        2005      2006  0.280452
#
#    standard_error     measure
# 0           0.030  prevalence
# 1           0.045  prevalence
# 2           0.019  prevalence
# 3           0.032  prevalence
# 4           0.047  prevalence

# %% [markdown]
# #### Try on a small subset of data

# %%
subset = np.random.choice(measurement.shape[0], size=500, replace=False)
data = measurement.iloc[subset,:].reset_index(drop=True)
import time
t0 = time.time()
covariate.interpolate(data, {'ldi': ldi, 'elevation': elevation, 'sev': sev}, population);
print('elapsed', time.time() - t0)
# Out:
# location_id              565
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2014
# year_end                2014
# mean              0.00284573
# standard_error    0.00110826
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 0, dtype: object
# location_id              565
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2014
# year_end                2014
# mean              0.00284573
# standard_error    0.00110826
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 0, dtype: object
# location_id              565
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2014
# year_end                2014
# mean              0.00284573
# standard_error    0.00110826
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 0, dtype: object
# location_id              548
# sex                     Male
# age_start                 45
# age_end                   49
# year_start              2010
# year_end                2010
# mean               0.0385946
# standard_error    0.00706905
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 1, dtype: object
# location_id              548
# sex                     Male
# age_start                 45
# age_end                   49
# year_start              2010
# year_end                2010
# mean               0.0385946
# standard_error    0.00706905
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 1, dtype: object
# location_id              548
# sex                     Male
# age_start                 45
# age_end                   49
# year_start              2010
# year_end                2010
# mean               0.0385946
# standard_error    0.00706905
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 1, dtype: object
# location_id              572
# sex                     Male
# age_start                 35
# age_end                   39
# year_start              2010
# year_end                2010
# mean              0.00451787
# standard_error    0.00153295
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 2, dtype: object
# location_id              572
# sex                     Male
# age_start                 35
# age_end                   39
# year_start              2010
# year_end                2010
# mean              0.00451787
# standard_error    0.00153295
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 2, dtype: object
# location_id              572
# sex                     Male
# age_start                 35
# age_end                   39
# year_start              2010
# year_end                2010
# mean              0.00451787
# standard_error    0.00153295
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 2, dtype: object
# location_id              537
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2014
# year_end                2014
# mean                0.565452
# standard_error     0.0347771
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 3, dtype: object
# location_id              537
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2014
# year_end                2014
# mean                0.565452
# standard_error     0.0347771
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 3, dtype: object
# location_id              537
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2014
# year_end                2014
# mean                0.565452
# standard_error     0.0347771
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 3, dtype: object
# location_id              570
# sex                     Male
# age_start                 60
# age_end                   64
# year_start              2011
# year_end                2011
# mean                0.108824
# standard_error     0.0179763
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 4, dtype: object
# location_id              570
# sex                     Male
# age_start                 60
# age_end                   64
# year_start              2011
# year_end                2011
# mean                0.108824
# standard_error     0.0179763
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 4, dtype: object
# location_id              570
# sex                     Male
# age_start                 60
# age_end                   64
# year_start              2011
# year_end                2011
# mean                0.108824
# standard_error     0.0179763
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 4, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              509
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2002
# year_end                2004
# mean                0.261854
# standard_error     0.0461127
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 5, dtype: object
# location_id              569
# sex                     Male
# age_start                 50
# age_end                   54
# year_start              2010
# year_end                2010
# mean               0.0643069
# standard_error      0.010811
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 6, dtype: object
# location_id              569
# sex                     Male
# age_start                 50
# age_end                   54
# year_start              2010
# year_end                2010
# mean               0.0643069
# standard_error      0.010811
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 6, dtype: object
# location_id              569
# sex                     Male
# age_start                 50
# age_end                   54
# year_start              2010
# year_end                2010
# mean               0.0643069
# standard_error      0.010811
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 6, dtype: object
# location_id              568
# sex                   Female
# age_start                 40
# age_end                   44
# year_start              2013
# year_end                2013
# mean               0.0144888
# standard_error     0.0129822
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 7, dtype: object
# location_id              568
# sex                   Female
# age_start                 40
# age_end                   44
# year_start              2013
# year_end                2013
# mean               0.0144888
# standard_error     0.0129822
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 7, dtype: object
# location_id              568
# sex                   Female
# age_start                 40
# age_end                   44
# year_start              2013
# year_end                2013
# mean               0.0144888
# standard_error     0.0129822
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 7, dtype: object
# location_id              572
# sex                   Female
# age_start                 45
# age_end                   49
# year_start              2011
# year_end                2011
# mean               0.0175635
# standard_error    0.00359712
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 8, dtype: object
# location_id              572
# sex                   Female
# age_start                 45
# age_end                   49
# year_start              2011
# year_end                2011
# mean               0.0175635
# standard_error    0.00359712
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 8, dtype: object
# location_id              572
# sex                   Female
# age_start                 45
# age_end                   49
# year_start              2011
# year_end                2011
# mean               0.0175635
# standard_error    0.00359712
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 8, dtype: object
# location_id              565
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2011
# year_end                2011
# mean                0.375004
# standard_error     0.0481435
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 9, dtype: object
# location_id              565
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2011
# year_end                2011
# mean                0.375004
# standard_error     0.0481435
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 9, dtype: object
# location_id              565
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2011
# year_end                2011
# mean                0.375004
# standard_error     0.0481435
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 9, dtype: object
# location_id              547
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2011
# year_end                2011
# mean                0.408456
# standard_error      0.142745
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 10, dtype: object
# location_id              547
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2011
# year_end                2011
# mean                0.408456
# standard_error      0.142745
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 10, dtype: object
# location_id              547
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2011
# year_end                2011
# mean                0.408456
# standard_error      0.142745
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 10, dtype: object
# location_id              543
# sex                     Male
# age_start                 20
# age_end                   24
# year_start              2014
# year_end                2014
# mean              0.00210483
# standard_error    0.00125489
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 11, dtype: object
# location_id              543
# sex                     Male
# age_start                 20
# age_end                   24
# year_start              2014
# year_end                2014
# mean              0.00210483
# standard_error    0.00125489
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 11, dtype: object
# location_id              543
# sex                     Male
# age_start                 20
# age_end                   24
# year_start              2014
# year_end                2014
# mean              0.00210483
# standard_error    0.00125489
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 11, dtype: object
# location_id              524
# sex                   Female
# age_start                 20
# age_end                   24
# year_start              2011
# year_end                2011
# mean               0.0012078
# standard_error    0.00634256
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 12, dtype: object
# location_id              524
# sex                   Female
# age_start                 20
# age_end                   24
# year_start              2011
# year_end                2011
# mean               0.0012078
# standard_error    0.00634256
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 12, dtype: object
# location_id              524
# sex                   Female
# age_start                 20
# age_end                   24
# year_start              2011
# year_end                2011
# mean               0.0012078
# standard_error    0.00634256
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 12, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              1995
# year_end                1996
# mean                0.203076
# standard_error     0.0626224
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 13, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              1995
# year_end                1996
# mean                0.203076
# standard_error     0.0626224
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 13, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              1995
# year_end                1996
# mean                0.203076
# standard_error     0.0626224
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 13, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              1995
# year_end                1996
# mean                0.203076
# standard_error     0.0626224
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 13, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              1995
# year_end                1996
# mean                0.203076
# standard_error     0.0626224
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 13, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              1995
# year_end                1996
# mean                0.203076
# standard_error     0.0626224
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 13, dtype: object
# location_id              529
# sex                   Female
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean               0.0787032
# standard_error     0.0307026
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 14, dtype: object
# location_id              529
# sex                   Female
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean               0.0787032
# standard_error     0.0307026
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 14, dtype: object
# location_id              529
# sex                   Female
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean               0.0787032
# standard_error     0.0307026
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 14, dtype: object
# location_id              525
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2012
# year_end                2012
# mean              0.00220247
# standard_error    0.00110753
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 15, dtype: object
# location_id              525
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2012
# year_end                2012
# mean              0.00220247
# standard_error    0.00110753
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 15, dtype: object
# location_id              525
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2012
# year_end                2012
# mean              0.00220247
# standard_error    0.00110753
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 15, dtype: object
# location_id              532
# sex                     Male
# age_start                 65
# age_end                   69
# year_start              2012
# year_end                2012
# mean                0.294366
# standard_error     0.0367459
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 16, dtype: object
# location_id              532
# sex                     Male
# age_start                 65
# age_end                   69
# year_start              2012
# year_end                2012
# mean                0.294366
# standard_error     0.0367459
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 16, dtype: object
# location_id              532
# sex                     Male
# age_start                 65
# age_end                   69
# year_start              2012
# year_end                2012
# mean                0.294366
# standard_error     0.0367459
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 16, dtype: object
# location_id              554
# sex                   Female
# age_start                  1
# age_end                    4
# year_start              2013
# year_end                2013
# mean              0.00410497
# standard_error    0.00265955
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 17, dtype: object
# location_id              554
# sex                   Female
# age_start                  1
# age_end                    4
# year_start              2013
# year_end                2013
# mean              0.00410497
# standard_error    0.00265955
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 17, dtype: object
# location_id              554
# sex                   Female
# age_start                  1
# age_end                    4
# year_start              2013
# year_end                2013
# mean              0.00410497
# standard_error    0.00265955
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 17, dtype: object
# location_id              525
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2011
# year_end                2011
# mean              0.00207665
# standard_error    0.00103424
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 18, dtype: object
# location_id              525
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2011
# year_end                2011
# mean              0.00207665
# standard_error    0.00103424
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 18, dtype: object
# location_id              525
# sex                     Male
# age_start                  5
# age_end                    9
# year_start              2011
# year_end                2011
# mean              0.00207665
# standard_error    0.00103424
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 18, dtype: object
# location_id              525
# sex                   Female
# age_start                 85
# age_end                   89
# year_start              2014
# year_end                2014
# mean                0.447979
# standard_error     0.0470369
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 19, dtype: object
# location_id              525
# sex                   Female
# age_start                 85
# age_end                   89
# year_start              2014
# year_end                2014
# mean                0.447979
# standard_error     0.0470369
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 19, dtype: object
# location_id              525
# sex                   Female
# age_start                 85
# age_end                   89
# year_start              2014
# year_end                2014
# mean                0.447979
# standard_error     0.0470369
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 19, dtype: object
# location_id              552
# sex                     Male
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean               0.0836921
# standard_error     0.0297455
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 20, dtype: object
# location_id              552
# sex                     Male
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean               0.0836921
# standard_error     0.0297455
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 20, dtype: object
# location_id              552
# sex                     Male
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean               0.0836921
# standard_error     0.0297455
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 20, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id              102
# sex                   Female
# age_start                 75
# age_end                   79
# year_start              1988
# year_end                2006
# mean                0.137018
# standard_error     0.0218282
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 21, dtype: object
# location_id             4749
# ...
# year_end                 2012
# mean               0.00137343
# standard_error    0.000836295
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 488, dtype: object
# location_id              525
# sex                   Female
# age_start                  1
# age_end                    4
# year_start              2010
# year_end                2010
# mean              0.00353101
# standard_error    0.00156208
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 489, dtype: object
# location_id              525
# sex                   Female
# age_start                  1
# age_end                    4
# year_start              2010
# year_end                2010
# mean              0.00353101
# standard_error    0.00156208
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 489, dtype: object
# location_id              525
# sex                   Female
# age_start                  1
# age_end                    4
# year_start              2010
# year_end                2010
# mean              0.00353101
# standard_error    0.00156208
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 489, dtype: object
# location_id             4749
# sex                     Male
# age_start                 60
# age_end                   69
# year_start              1996
# year_end                1997
# mean               0.0770356
# standard_error     0.0476236
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 490, dtype: object
# location_id             4749
# sex                     Male
# age_start                 60
# age_end                   69
# year_start              1996
# year_end                1997
# mean               0.0770356
# standard_error     0.0476236
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 490, dtype: object
# location_id             4749
# sex                     Male
# age_start                 60
# age_end                   69
# year_start              1996
# year_end                1997
# mean               0.0770356
# standard_error     0.0476236
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 490, dtype: object
# location_id             4749
# sex                     Male
# age_start                 60
# age_end                   69
# year_start              1996
# year_end                1997
# mean               0.0770356
# standard_error     0.0476236
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 490, dtype: object
# location_id             4749
# sex                     Male
# age_start                 60
# age_end                   69
# year_start              1996
# year_end                1997
# mean               0.0770356
# standard_error     0.0476236
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 490, dtype: object
# location_id             4749
# sex                     Male
# age_start                 60
# age_end                   69
# year_start              1996
# year_end                1997
# mean               0.0770356
# standard_error     0.0476236
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 490, dtype: object
# location_id              544
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2011
# year_end                2011
# mean                0.448606
# standard_error     0.0454782
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 491, dtype: object
# location_id              544
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2011
# year_end                2011
# mean                0.448606
# standard_error     0.0454782
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 491, dtype: object
# location_id              544
# sex                     Male
# age_start                 85
# age_end                   89
# year_start              2011
# year_end                2011
# mean                0.448606
# standard_error     0.0454782
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 491, dtype: object
# location_id              544
# sex                     Male
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean                0.105898
# standard_error     0.0182579
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 492, dtype: object
# location_id              544
# sex                     Male
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean                0.105898
# standard_error     0.0182579
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 492, dtype: object
# location_id              544
# sex                     Male
# age_start                 55
# age_end                   59
# year_start              2000
# year_end                2000
# mean                0.105898
# standard_error     0.0182579
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 492, dtype: object
# location_id              562
# sex                   Female
# age_start                 40
# age_end                   44
# year_start              2010
# year_end                2010
# mean               0.0212969
# standard_error    0.00742154
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 493, dtype: object
# location_id              562
# sex                   Female
# age_start                 40
# age_end                   44
# year_start              2010
# year_end                2010
# mean               0.0212969
# standard_error    0.00742154
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 493, dtype: object
# location_id              562
# sex                   Female
# age_start                 40
# age_end                   44
# year_start              2010
# year_end                2010
# mean               0.0212969
# standard_error    0.00742154
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 493, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              2010
# year_end                2010
# mean                0.382909
# standard_error       0.11567
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 494, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              2010
# year_end                2010
# mean                0.382909
# standard_error       0.11567
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 494, dtype: object
# location_id             4749
# sex                     Male
# age_start                 70
# age_end                   79
# year_start              2010
# year_end                2010
# mean                0.382909
# standard_error       0.11567
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 494, dtype: object
# location_id              550
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2010
# year_end                2010
# mean                0.426302
# standard_error      0.259689
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 495, dtype: object
# location_id              550
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2010
# year_end                2010
# mean                0.426302
# standard_error      0.259689
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 495, dtype: object
# location_id              550
# sex                     Male
# age_start                 95
# age_end                   99
# year_start              2010
# year_end                2010
# mean                0.426302
# standard_error      0.259689
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 495, dtype: object
# location_id              545
# sex                     Male
# age_start                 70
# age_end                   74
# year_start              2010
# year_end                2010
# mean                0.318906
# standard_error     0.0381986
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 496, dtype: object
# location_id              545
# sex                     Male
# age_start                 70
# age_end                   74
# year_start              2010
# year_end                2010
# mean                0.318906
# standard_error     0.0381986
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 496, dtype: object
# location_id              545
# sex                     Male
# age_start                 70
# age_end                   74
# year_start              2010
# year_end                2010
# mean                0.318906
# standard_error     0.0381986
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 496, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               43
# sex                   Female
# age_start                 90
# age_end                   94
# year_start              2012
# year_end                2014
# mean                0.381858
# standard_error      0.302117
# measure           prevalence
# ldi                        0
# elevation                  0
# sev                        0
# Name: 497, dtype: object
# location_id               528
# sex                    Female
# age_start                  25
# age_end                    29
# year_start               2013
# year_end                 2013
# mean              0.000296711
# standard_error    0.000480205
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 498, dtype: object
# location_id               528
# sex                    Female
# age_start                  25
# age_end                    29
# year_start               2013
# year_end                 2013
# mean              0.000296711
# standard_error    0.000480205
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 498, dtype: object
# location_id               528
# sex                    Female
# age_start                  25
# age_end                    29
# year_start               2013
# year_end                 2013
# mean              0.000296711
# standard_error    0.000480205
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 498, dtype: object
# location_id               570
# sex                    Female
# age_start                   5
# age_end                     9
# year_start               2013
# year_end                 2013
# mean               0.00101003
# standard_error    0.000714256
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 499, dtype: object
# location_id               570
# sex                    Female
# age_start                   5
# age_end                     9
# year_start               2013
# year_end                 2013
# mean               0.00101003
# standard_error    0.000714256
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 499, dtype: object
# location_id               570
# sex                    Female
# age_start                   5
# age_end                     9
# year_start               2013
# year_end                 2013
# mean               0.00101003
# standard_error    0.000714256
# measure            prevalence
# ldi                         0
# elevation                   0
# sev                         0
# Name: 499, dtype: object
# elapsed 36.334731578826904

# %%
data.head()
# Out:
#    location_id   sex  age_start  age_end  year_start  year_end      mean  \
# 0          565  Male          5        9        2014      2014  0.002846
# 1          548  Male         45       49        2010      2010  0.038595
# 2          572  Male         35       39        2010      2010  0.004518
# 3          537  Male         95       99        2014      2014  0.565452
# 4          570  Male         60       64        2011      2011  0.108824
#
#    standard_error     measure        ldi  elevation       sev
# 0        0.001108  prevalence  43221.145   0.000006  2.251331
# 1        0.007069  prevalence  44220.855   0.000000  2.338293
# 2        0.001533  prevalence  46588.145   0.000000  2.236901
# 3        0.034777  prevalence  43158.609   0.000000  2.313815
# 4        0.017976  prevalence  51800.535   0.000097  2.129749

# %%
data.to_csv('./data/copd/copd_small_cov.csv')
